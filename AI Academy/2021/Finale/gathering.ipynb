# %% [markdown]
# # Prepare

# %%
from IPython.core.interactiveshell import InteractiveShell
import json
import os, re
import pandas as pd
import numpy as np
import time
import random
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
import ast
import math
from jupyterthemes import jtplot

jtplot.style(theme='chesterish')

# %%
def load_jsonl(jsonl):
    with open(jsonl, 'r') as file:
        return [json.loads(line) for line in list(file)]


def load_json(file):
    with open(file, 'r') as f:
        return json.load(f)

# %%
cat_features = []

# %% [markdown]
# # Load

# %%
raw_validation, raw_test = load_jsonl('data/val.jsonl'), load_jsonl('data/test.jsonl')

# %%
for corpus in raw_validation:
    corpus['is_answered'] = True
for corpus in raw_test:
    corpus['is_answered'] = False

# %%
data = raw_validation + raw_test

# %%
for idx, item in enumerate(data):
    item['idx'] = idx
    for q in item['qas']:
        q['idx'] = idx

# %% [markdown]
# # Translate

# %%
def standardize(txt):
    return txt.replace('\n', '').replace('@highlight', '')

# %%
translated_answers, translated_questions, translated_texts = load_json(
    'data/answers_all.json'), load_json('data/questions_validation.json'), load_json(
        'data/texts_test.json')
translated_texts.update(load_json('data/texts_validation.json'))
translated_questions.update(load_json('data/questions_test.json'))

# %%
def translate(text, kind='text'):
    if kind == 'text':
        return translated_texts[text]
    elif kind == 'question':
        return translated_questions[text]
    elif kind == 'answer':
      return translated_answers[text]

# %%
for k, v in list(translated_answers.items()):
  translated_answers[k.strip()] = v.strip()

# %%
def fillthegaps():
    global translated_texts
    translated_texts['Обвинения в причастности к парижским терактам предъявлены в Бельгии уже восьми задержанным. Один из организаторов взрывов был перед терактами в Будапеште. В Бельгии задержаны еще два подозреваемых в связи с терактами в Париже, один из них гражданин Франции, второй - подданный Бельгии. Их обвиняют в участии в действиях, связанных с терроризмом, сообщили в четверг, 3 декабря, в генпрокуратуре в Брюсселе. Они останутся под арестом в течение месяца. Олланд постарался убедить мировых лидеров в необходимости более интенсивной борьбы с ИГ.В Германии за сутки выявлено более 100 новых заражений коронавирусомТысячи демонстрантов в Гамбурге выступили за прием беженцевКомментарий: Россия накануне эпидемии - виноватые назначены заранее'] = "Already eight detainees have been charged with involvement in the Paris terrorist attacks in Belgium. One of the organizers of the explosions was before the attacks in Budapest. In Belgium, two more suspects were detained in connection with the terrorist attacks in Paris, one of them is a citizen of France, the other is a citizen of Belgium. They are accused of participation in acts related to terrorism, reported on Thursday, December 3, at the Prosecutor General's Office in Brussels. They will remain under arrest for a month. Hollande tried to convince world leaders of the need for a more intense fight against IS. More than 100 new coronavirus infections were detected in Germany per day Thousands of demonstrators in Hamburg spoke in favor of accepting refugees."
    translated_texts['В Саитаме (Япония) пожилую женщину госпитализировали с подозрением на заражение вирусом Эбола. Об этом сообщает РИА Новости со ссылкой на агентство Киодо. Уточняется, что ранее 70-летняя японка посещала Демократическую Республику Конго. У нее была зафиксирована температура более 38 градусов. Пенсионерку доставили в одну из больниц Токио для выявления в ее крови вируса Эбола. В кризисном штабе при канцелярии премьер-министра Японии Синдзо Абэ уже была создана группа по сбору и анализу информации. Смертельный вирус достиг международного масштаба Смертельный вирус проник в еще одну страну Африки «Русал» и Минздрав завершили вакцинацию против Эболы в Гвинее'] = "In Saitama, Japan, an elderly woman was hospitalized with suspected Ebola infection. This was reported by RIA Novosti with reference to the Kyodo agency. It is specified that the 70-year-old Japanese woman previously visited the Democratic Republic of the Congo. She had a temperature of more than 38 degrees. The pensioner was taken to a hospital in Tokyo to be diagnosed with the Ebola virus in her blood. A group for collecting and analyzing information has already been set up in the crisis headquarters under the office of Japanese Prime Minister Shinzo Abe. The deadly virus has reached an international scale The deadly virus has penetrated another African country Rusal and the Ministry of Health completed vaccination against Ebola in Guinea"
    translated_texts['Физики из Университета Глазго обнаружили парадокс теории Эйнштейна, который может нарушать основополагающий принцип равноправия инерциальных систем отсчета (ИСО) и тем самым ставит под угрозу физическую картину мира. Объяснение противоречия было предложено в Journal of Modern Optics. Кратко об исследовании рассказывает издание Gizmodo. Согласно принципу относительности для разных ИСО, представленных покоящимися и двигающимися телами, законы физики проявляются одинаково. Однако ученые выяснили, что этот принцип может не выполняться для движущихся возбужденных атомов. Парадокс заключается в том, что атомы могут спонтанно испускать фотоны, но при этом на частицы света распространяется эффект Доплера. Представлено новое подтверждение общей теории относительности Существование машины времени доказали математически Физики запутали рекордное количество атомов'] = "Physicists from the University of Glasgow discovered the paradox of Einstein's theory, which can violate the fundamental principle of equality of inertial reference systems (IRF) and thereby endanger the physical picture of the world. An explanation for the controversy was suggested in the Journal of Modern Optics. The research is briefly described by the publication Gizmodo. According to the principle of relativity for different IFRs, represented by bodies at rest and moving bodies, the laws of physics manifest themselves in the same way. However, scientists have found that this principle may not hold for moving excited atoms. The paradox is that atoms can spontaneously emit photons, but the Doppler effect applies to light particles. New confirmation of general relativity presented The existence of a time machine has been proven mathematically Physicists have entangled a record number of atoms"
    translated_texts['Бывший президент Франции Николя Саркози подверг критике подход нынешнего главы государства Франсуа Олланда к отношениям с Москвой. Его слова приводит ТАСС. «Я сожалею о политике, которая проводится ныне в отношении России», — заявил он журналистам, комментируя известие об отмене визита в Париж президента Владимира Путина. Саркози, намеревающийся баллотироваться в 2017 году на пост президента, предостерег от «вступления в новую холодную войну». По его словам, «долг и обязанность Франции и Европы — вести диалог с Россией». «Как можно урегулировать ситуацию, если общаться друг с другом лишь посредством пресс-релизов?» — сказал Саркози.Олланд отказался считать отмену визита Путина помехой для дискуссии по СирииВо Франции сообщили об отмене визита Путина в ПарижПесков объяснил отмену визита Путина в Париж'] = """Former French President Nicolas Sarkozy criticized the current head of state François Hollande's approach to relations with Moscow. His words are quoted by TASS. “I regret the current policy towards Russia,” he told reporters, commenting on the news of the cancellation of President Vladimir Putin’s visit to Paris. Sarkozy, intending to run for president in 2017, has warned against "entering a new cold war." According to him, "the duty and obligation of France and Europe is to conduct a dialogue with Russia." "How can you resolve the situation if you communicate with each other only through press releases?" - Sarkozy said. Hollande refused to consider the cancellation of Putin's visit as a hindrance to the discussion on Syria France announced the cancellation of Putin's visit to Paris Sands explained the cancellation of Putin's visit to Paris"""
    translated_texts['Президент России Владимир Путин заявил, что выступает за бессрочный закон об особом статусе Донбасса. Об этом он заявил на пресс-конференции после переговоров с канцлером Германии Ангелой Меркель в Кремле, передает «Интерфакс». Глава государства призвал руководство Украины начать реализацию минских соглашений, несмотря на внутриполитические проблемы. «Мы понимаем все сложности внутриполитического процесса на Украине, но, если все заинтересованные стороны хотят добиться окончательного урегулирования, нужно идти по реализации минских соглашений», — сказал Путин. Он также отметил, что на переговорах с канцлером Германии «подробно обсуждалось» урегулирование внутриукраинского кризиса. Ранее министр иностранных дел Украины Вадим Пристайко заявил, что принятие «формулы Штайнмайера» не означает проведения выборов в Донбассе любой ценой.Украина отказалась проводить выборы в Донбассе любой ценойОписаны пять сценариев развития ситуации в ДонбассеНа Украине раскрыли план по введению «формулы Штайнмайера» в законодательство'] = """Russian President Vladimir Putin said he was in favor of an unlimited law on the special status of Donbass. He stated this at a press conference after talks with German Chancellor Angela Merkel in the Kremlin, Interfax reports. The head of state called on the Ukrainian leadership to start implementing the Minsk agreements, despite the internal political problems. “We understand all the complexities of the internal political process in Ukraine, but if all interested parties want to achieve a final settlement, we need to follow the implementation of the Minsk agreements,” Putin said. He also noted that during the talks with the German Chancellor, the settlement of the internal Ukrainian crisis was "discussed in detail". Earlier, the Minister of Foreign Affairs of Ukraine Vadim Prystaiko said that the adoption of the "Steinmeier formula" does not mean holding elections in Donbass at any cost."""

fillthegaps()

# %%
for item in data:
    passage = item['passage']
    question = standardize(item['qas'][0]['query'])
    item['qas'][0]['query_en'] = translate(standardize(item['qas'][0]['query']), kind='question')
    for entity in passage['entities']:
        entity['text'] = passage['text'][entity['start']:entity['end']]
        entity['text_en'] = translate(passage['text'][entity['start']:entity['end']].strip(), kind='answer')
        if 'answers' in item['qas'][0]:
            entity['label'] = 0
    if 'answers' in item['qas'][0]:
        for entity in item['qas'][0]['answers']:
            for e in passage['entities']:
                if entity['start'] == e['start'] and entity['end'] == e['end']:
                    e['label'] = 1
    passage['text_en'] = translate(standardize(passage['text']), kind='text')
    passage['text'] = passage['text']

# %% [markdown]
# # Make flatten

# %%
def simplify_data(d, split_answers=False, use_en=True):
    simplified = []
    temp = {}
    for item in d:
        temp['context_ru'] = item['passage']['text']
        temp['question_ru'] = item['qas'][0]['query']
        if use_en:
            temp['context_en'] = item['passage']['text_en']
            temp['question_en'] = item['qas'][0]['query_en']
        temp['is_answered'] = item['is_answered']
        if split_answers:
            for entity in set([tuple(x.items()) for x in item['passage']['entities']]):
                entity = dict(entity)
                temp['answer_ru'] = entity['text']
                temp['start'] = entity['start']
                temp['end'] = entity['end']
                temp['old_idx'] = item['idx']
                if use_en:
                    temp['answer_en'] = entity['text_en']
                if item['is_answered']:
                    temp['label'] = entity['label']
                simplified.append(temp.copy())
        else:
            temp['answers'] = item['passage']['entities']
            simplified.append(temp.copy())
    return simplified

# %%
train = pd.DataFrame(list(simplify_data(data, split_answers=True)))

# %%
train = train.drop_duplicates(['context_ru', 'question_ru', 'answer_ru'])

# %%
train = train.reset_index().drop(columns=['index'])

# %%
train.head()
# Out:
#                                           context_ru  \
# 0  Главной темой переговоров наряду с прежними сп...
# 1  Главной темой переговоров наряду с прежними сп...
# 2  Главной темой переговоров наряду с прежними сп...
# 3  Главной темой переговоров наряду с прежними сп...
# 4  Главной темой переговоров наряду с прежними сп...
#
#                                          question_ru  \
# 0  В него вошли @placeholder, Россия, Украина и Ф...
# 1  В него вошли @placeholder, Россия, Украина и Ф...
# 2  В него вошли @placeholder, Россия, Украина и Ф...
# 3  В него вошли @placeholder, Россия, Украина и Ф...
# 4  В него вошли @placeholder, Россия, Украина и Ф...
#
#                                           context_en  \
# 0  The main topic of the talks, along with previo...
# 1  The main topic of the talks, along with previo...
# 2  The main topic of the talks, along with previo...
# 3  The main topic of the talks, along with previo...
# 4  The main topic of the talks, along with previo...
#
#                                          question_en  is_answered  answer_ru  \
# 0  It includes @placeholder, Russia, Ukraine and ...         True   Донбасса
# 1  It includes @placeholder, Russia, Ukraine and ...         True    Украину
# 2  It includes @placeholder, Russia, Ukraine and ...         True  Мариуполе
# 3  It includes @placeholder, Russia, Ukraine and ...         True     Россия
# 4  It includes @placeholder, Russia, Ukraine and ...         True       Маса
#
#    start   end  old_idx answer_en  label
# 0    173   181        0   Donbass      0
# 1    409   416        0   Ukraine      0
# 2    429   438        0  Mariupol      0
# 3   1246  1252        0    Russia      0
# 4    881   885        0      Masa      0

# %% [markdown]
# # Yammy Features

# %% [markdown]
# ## General

# %%
def harmonic_mean(arr):
    n = len(arr)
    if n == 0:
        return 0
    s = 0
    for i in arr:
        if i == 0:
            i = 10 ** -10
        s += 1 / i
    return n / s if s != 0 else 10 ** -10


def geometric_mean(arr):
    n = len(arr)
    if n == 0:
        return 0
    res = 1
    for i in arr:
        res = res * (i**(1 / n))
    return res


def square_mean(arr):
    n = len(arr)
    if n == 0:
        return 0
    s = 0
    for i in arr:
        s += i * i
    return math.sqrt(s / n)


def mmmm(feature, where=None, by=None, function=None):
    if where is None:
        where = train
    if by == 'context_idx':
        return where
    assert by != None, 'Missing required \'by\' parameter!'
    temp = where[[feature, by]].groupby([by]).agg(
        ['mean', 'std', 'median', 'max', 'min', 'sum', square_mean, geometric_mean, harmonic_mean])
    temp.columns = [
        '_'.join(col).strip() + '_by_' + by.split('_')[0]
        for col in temp.columns.values
    ]
    return pd.merge(temp, where, on=by)

# %% [markdown]
# ## Dumb features

# %%
for feature in ['context', 'question', 'answer']:
    for locale in ['ru', 'en']:
        train['words_amount_in_' + feature + '_' + locale] = [t.count(' ') + 1 for t in train[feature + '_' + locale]]

# %%
for feature in ['context', 'question', 'answer']:
    train['words_amount_in_' + feature +
          '_difference'] = train['words_amount_in_' + feature +
                                 '_ru'] - train['words_amount_in_' + feature +
                                                '_en']

# %%
for feature in ['context', 'question', 'answer']:
    for locale in ['ru', 'en']:
        for by in ['old_idx']:
            train = mmmm('words_amount_in_' + feature + '_' + locale, by=by)

# %%
for feature in ['context', 'question']:
    for locale in ['ru', 'en']:
        train['amount_answers_in_' + feature + '_' + locale] = [t.count(a) + 1 for t, a in train[[feature + '_' + locale, 'answer_' + locale]].values]

# %%
for feature in ['context', 'question']:
    for locale in ['ru', 'en']:
        for by in ['old_idx']:
            train = mmmm('amount_answers_in_' + feature + '_' + locale, by=by)

# %%
alphabet = [chr(i) for i in range(ord('А'),ord('А')+64)] + list('1234567890') + [' ']

# %%
from langdetect import detect
result = []
for answer in tqdm(train['answer_ru'].values):
    if all(map(lambda x: True if x in alphabet else False, answer)):
        result.append('ru')
    else:
        result.append('en')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
train['answer_language_manual'] = result

# %%
cat_features.append('answer_language_manual')

# %%
train[['answer_language', 'answer_language_manual', 'answer_ru']]
# Out:
#        answer_language answer_language_manual        answer_ru
# 0                   ru                     ru         Донбасса
# 1                   uk                     ru          Украину
# 2                   mk                     ru        Мариуполе
# 3                   ru                     ru           Россия
# 4                   bg                     ru             Маса
# ...                ...                    ...              ...
# 143059              mk                     ru      Синиша Мали
# 143060              ru                     ru      РИА Новости
# 143061              ru                     ru  Александр Вучич
# 143062              ru                     ru           Сербия
# 143063              ru                     ru           России
#
# [143064 rows x 3 columns]

# %% [markdown]
# # Tokenizing

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.8/site-packages (3.5)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.8/site-packages (from nltk) (1.0.0)
# Requirement already satisfied: regex in /opt/conda/lib/python3.8/site-packages (from nltk) (2020.11.13)
# Requirement already satisfied: click in /opt/conda/lib/python3.8/site-packages (from nltk) (7.1.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.8/site-packages (from nltk) (4.41.1)

# %%
import nltk
nltk.download("stopwords")
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, SnowballStemmer
# Out:
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
stemmers = {'ru': SnowballStemmer('russian'), 'en': PorterStemmer()}

# %%
stop_words = {'ru': set(stopwords.words("russian")), 'en': set(stopwords.words("english"))}

# %%
tokenize = lambda text: nltk.word_tokenize(text)

# %%
stemmerize = lambda text, locale: set([stemmers[locale].stem(word) for word in nltk.word_tokenize(text) if not word.lower() in stop_words[locale] and word[0].isalpha()])

# %%
stemmed = {}

for locale in ['ru', 'en']:
    temp = []
    for corpus in tqdm(simplify_data(data, split_answers=False)):
        words_in_context = stemmerize(corpus['context_' + locale], locale)
        words_in_question = stemmerize(corpus['question_' + locale], locale)
        for answer in corpus['answers']:
            words_in_answer = stemmerize(answer['text' + ('_en' if locale == 'en' else '')], locale)
            temp.append({'stemmed_context_' + locale: words_in_context, 
                             'stemmed_question_' + locale: words_in_question, 
                             'stemmed_answer_' + locale: words_in_answer})
    stemmed[locale] = temp
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14834.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=14834.0), HTML(value='')))

# %%
train = pd.concat([train, pd.DataFrame(stemmed['ru'])], axis=1)
train = pd.concat([train, pd.DataFrame(stemmed['en'])], axis=1)

# %%
for feature in ['context', 'question', 'answer']:
    for locale in ['ru', 'en']:
        train['stems_amount_in_' + feature + '_' + locale] = [len(t) for t in train['stemmed_' + feature + '_' + locale]]

# %%
for locale in ['ru', 'en']:
    train = pd.concat([train, pd.DataFrame([{'same_words_answer_question_' + locale: len(a & q), 
      'same_words_context_quesiton_' + locale: len(q & c), 
      'same_words_context_answer_' + locale: len(a & c)} for c, q, a in train[['stemmed_context_' + locale, 'stemmed_question_' + locale, 'stemmed_answer_' + locale]].values])], axis=1)

# %%
for feature in ['answer']:
    for locale in ['ru', 'en']:
        train['stems_same_stems_ratio_' + feature + '_' + locale] = train['stems_amount_in_' + feature + '_' + locale] / train['stems_amount_in_' + feature + '_' + locale]

# %%
for locale in ['ru', 'en']:
    for feature in ['same_words_answer_question', 'same_words_context_quesiton', 'same_words_context_answer', 'stems_same_stems_ratio_answer']:
        train = mmmm(feature + '_' + locale, by='old_idx')

# %%
import pymorphy2
morph = pymorphy2.MorphAnalyzer()

# %%
result = {}
for i, answer in enumerate(tqdm(train['answer_ru'].values)):
    parsed = morph.parse(answer)[0]
    result[i] = {'answer_ru_part_of_speach': parsed.tag.POS}
    for k, v in result[i].items():
        if v == None:
            result[i][k] = 'NONE'
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
train = pd.concat([train, pd.DataFrame(result).T], axis=1)

# %%
cat_features += list(result[0].keys())
#cat_features.remove('answer_ru_morph_score')

# %%
train.to_csv('data.csv')

# %% [markdown]
# # Windows

# %%
result = {}
for locale in 'ru',:
    for index, (start, end, text) in tqdm(list(enumerate(train[['start', 'end', 'context_' + locale]].values))):
        start, end = int(start), int(end)
        i = len(text[:start].split())
        new_text = [''.join(filter(lambda x: x.isalpha() or x == ' ' or x == '-', y)) for y in (text[:start] + text[end:]).split()]
        r = {'word_behind_entity_' + locale + '_in_context': 
             (new_text[i-1] if 0 < i < len(new_text) and new_text[i-1] != 'highlight' and new_text[i-1] != 'header' and text[start-2] not in '.,?!\n' else '-'), 'word_after_entity_' + locale + '_in_context': (new_text[i] if i < len(new_text) and new_text[i] != 'highlight' and new_text[i] != 'header' and (end == len(text)-1 or text[end+1] not in '.,?!\n') else '-')}
        if index not in result:
            result[index] = r
        else:
            result[index].update(r)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
for locale in 'ru',:
    for index, (start, end, text) in tqdm(list(enumerate(train[['start', 'end', 'context_' + locale]].values))):
        start, end = int(start), int(end)
        i = len(text[:start].split())
        new_text = [''.join(filter(lambda x: x.isalpha() or x == ' ' or x == '-', y)) for y in (text[:start] + text[end:]).split()]
        r = {'word_behind_behind_entity_' + locale + '_in_context': 
             (new_text[i-2] if 1 < i < len(new_text) and new_text[i-2] != 'highlight' and new_text[i-2] != 'header' and text[start-2] not in '.,?!\n' else '-'), 
             'word_after_after_entity_' + locale + '_in_context': 
             (new_text[i+1] if i+1 < len(new_text) and new_text[i+1] != 'highlight' and new_text[i+1] != 'header' and (end == len(text)-1 or text[end+1] not in '.,?!\n') else '-')}
        if index not in result:
            result[index] = r
        else:
            result[index].update(r)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
for locale in 'ru',:
    for index, (text,) in tqdm(list(enumerate(train[['question_' + locale]].values))):
        start, end = text.find('@placeholder'), text.find('@placeholder') + len('@placeholder')
        i = len(text[:start].split())
        new_text = [''.join(filter(lambda x: x.isalpha() or x == ' ' or x == '-', y)) for y in (text[:start] + text[end:]).split()]
        r = {'word_behind_entity_' + locale + '_in_question': 
             (new_text[i-1] if 0 < i < len(new_text) and new_text[i-1] != 'highlight' and new_text[i-1] != 'header' and text[start-2] not in '.,?!\n' else '-'), 
             'word_after_entity_' + locale + '_in_question': (new_text[i] if i < len(new_text) and new_text[i] != 'highlight' and new_text[i] != 'header' and (end == len(text)-1 or text[end+1] not in '.,?!\n') else '-')}
        if index not in result:
            result[index] = r
        else:
            result[index].update(r)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
for locale in 'ru',:
    for index, (text,) in tqdm(list(enumerate(train[['question_' + locale]].values))):
        start, end = text.find('@placeholder'), text.find('@placeholder') + len('@placeholder')
        i = len(text[:start].split())
        new_text = [''.join(filter(lambda x: x.isalpha() or x == ' ' or x == '-', y)) for y in (text[:start] + text[end:]).split()]
        r = {'word_behind_behind_entity_' + locale + '_in_question': 
             (new_text[i-2] if 1 < i < len(new_text) and new_text[i-2] != 'highlight' and new_text[i-2] != 'header' and text[start-2] not in '.,?!\n' else '-'), 
             'word_after_after_entity_' + locale + '_in_question': (new_text[i+1] if i+1 < len(new_text) and new_text[i+1] != 'highlight' and new_text[i+1] != 'header' and (end == len(text)-1 or text[end+1] not in '.,?!\n') else '-')}
        if index not in result:
            result[index] = r
        else:
            result[index].update(r)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
text_features = []

# %%
text_features += list(list(result.items())[2][1].keys())

# %%
cat_features += list(list(result.items())[2][1].keys())

# %%
train = pd.concat([train, pd.DataFrame(result).T], axis=1)

# %%
glossary = set()
for i in list(result.items()):
    for j in list(i[1].values()):
        glossary.add(j.lower())

# %%
dictionary = {}
for k in glossary:
    parsed = morph.parse(k)[0]
    dictionary[k] = parsed.tag.POS

# %%
dictionary

# %%
answers = {}
for k, d in result.items():
    for f, w in d.items():
        if k in answers:
            answers[k][f + '_part_of_speach'] = dictionary[w.lower()] if dictionary[w.lower()] != None else 'NONE'
        else:
            answers[k] = {f + '_part_of_speach': dictionary[w.lower()] if dictionary[w.lower()] != None else 'NONE'}

# %%
train = pd.concat([train, pd.DataFrame(answers).T], axis=1)

# %%
train.head()

# %%
cat_features += list(list(answers.items())[2][1].keys())

# %% [markdown]
# # Encoding

# %%
import gc
gc.collect()
# Out:
# 15

# %%
from sentence_transformers import util
from sentence_transformers import SentenceTransformer, util

# %%
cosine_similarity = lambda a, b: util.pytorch_cos_sim(a, b)[0][0].item()

# %%
encoder = SentenceTransformer('stsb-roberta-large')

# %% [markdown]
# # MultiRC

# %%
val_mrc = list(np.load('data/multircformat_val.npy'))
test_mrc = list(np.load('data/multircformat_test_first8832.npy')) + list(np.load('data/multircformat_testfrom8896.npy'))

# %%
multirc = val_mrc + test_mrc

# %%
result = {}
counter = 0
for old_idx in tqdm(set(train['old_idx'].values)):
    answers = len(list(set([str(i) for i in train[train['old_idx'] == old_idx]['answer_ru'].values])))
    result[old_idx] = sum(multirc[counter:counter+answers])
    counter+=answers
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14834.0), HTML(value='')))

# %%
train = pd.merge(train, pd.Series(result).reset_index().rename(columns={'index': 'old_idx', 0: 'multirc'}), on='old_idx')

# %%
for feature in 'multirc',:
    train = mmmm(feature, by='old_idx')

# %% [markdown]
# # T5

# %%
from fuzzywuzzy import fuzz

# %%
test_beatlesfan = [i.strip('\n') for i in open('beatlesfan.txt', 'r').readlines()]
val_beatlesfan = [i.strip('\n') for i in open('beatlesfan_val.txt', 'r').readlines()]

# %%
result = {}
for text_idx, answer in tqdm(list(enumerate(val_beatlesfan + test_beatlesfan))):
    encoded_answer = encoded_answers[answer] if answer in encoded_answers else encoder.encode(answer)
    for k, v in dict(train[train['old_idx']==text_idx]['answer_en']).items():
        try:
            encoded_variant = encoded_answers[v]
            result[k] = {'t5_beatles_record_fuzz_ratio':  (fuzz.ratio(v, answer) / 100), 
                     't5_beatles_record_fuzz_partial_ratio':  (fuzz.partial_ratio(v, answer) / 100),
                     't5_beatles_record_roberta_simmilarity':  cosine_similarity(encoded_answer, encoded_variant)}
        except:
            print('exception!')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14834.0), HTML(value='')))
# exception!
# exception!

# %%
train = pd.concat([train, pd.DataFrame(result).T], axis=1)

# %%
for feature in result[0].keys():
    train = mmmm(feature, by='old_idx')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:252: ComplexWarning: Casting complex values to real discards the imaginary part
#   return result.astype(dtype)

# %% [markdown]
# # Top

# %%
val_top3 = np.load('data/val_top3.npy', allow_pickle=True)
test_top3 = np.load('data/test_top3.npy', allow_pickle=True)

# %%
opa = list(set([str(i) for i in train['answer_en'].values]))

# %%
encodes = encoder.encode(opa, show_progress_bar=True)

# %%
encoded_answers = {}
for i in range(len(opa)):
    encoded_answers[opa[i]] = encodes[i]

# %%
encoded_answers = np.load('encoded_answers.npy', allow_pickle=True).item()

# %%
encoded_answers

# %%
result = {}
for text_idx, top in tqdm(list(enumerate(list(val_top3)[:len(raw_validation)] + list(test_top3)[:len(raw_test)]))):
    encoded_entities = [encoded_answers[i] if i in encoded_answers else encoder.encode(top) for i in top]
    for k, v in dict(train[train['old_idx']==text_idx]['answer_en']).items():
        try:
            encoded_answer = encoded_answers[v]
            result[k] = {'t5_3b_record_top1_fuzz_ratio':  (fuzz.ratio(top[0], v) / 100) if top else 0, 
                     't5_3b_record_top2_fuzz_ratio':  (fuzz.ratio(top[1], v) / 100) if len(top) > 1 else 0, 
                     't5_3b_record_top3_fuzz_ratio':  (fuzz.ratio(top[2], v) / 100) if len(top) == 3 else 0,
                     't5_3b_record_top1_fuzz_partial_ratio':  (fuzz.partial_ratio(top[0], v) / 100) if top else 0, 
                     't5_3b_record_top2_fuzz_partial_ratio':  (fuzz.partial_ratio(top[1], v) / 100) if len(top) > 1 else 0, 
                     't5_3b_record_top3_fuzz_partial_ratio':  (fuzz.partial_ratio(top[2], v) / 100) if len(top) == 3 else 0,
                     't5_3b_record_top1_roberta_simmilarity':  cosine_similarity(encoded_entities[0], encoded_answer) if top else 0,
                     't5_3b_record_top2_roberta_simmilarity':  cosine_similarity(encoded_entities[1], encoded_answer) if len(top) > 1 else 0,
                     't5_3b_record_top3_roberta_simmilarity':  cosine_similarity(encoded_entities[2], encoded_answer) if len(top) == 3 else 0}


        except:
            print('exception')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14834.0), HTML(value='')))
# exception
# exception

# %%
train = pd.concat([train, pd.DataFrame(result).T], axis=1)

# %%
train.head()
# Out:
#    old_idx  t5_beatles_record_roberta_simmilarity_mean_by_old  \
# 0        0                                           0.350735
# 1        0                                           0.350735
# 2        0                                           0.350735
# 3        0                                           0.350735
# 4        0                                           0.350735
#
#    t5_beatles_record_roberta_simmilarity_std_by_old  \
# 0                                          0.283964
# 1                                          0.283964
# 2                                          0.283964
# 3                                          0.283964
# 4                                          0.283964
#
#    t5_beatles_record_roberta_simmilarity_median_by_old  \
# 0                                            0.29663
# 1                                            0.29663
# 2                                            0.29663
# 3                                            0.29663
# 4                                            0.29663
#
#    t5_beatles_record_roberta_simmilarity_max_by_old  \
# 0                                               1.0
# 1                                               1.0
# 2                                               1.0
# 3                                               1.0
# 4                                               1.0
#
#    t5_beatles_record_roberta_simmilarity_min_by_old  \
# 0                                         -0.031259
# 1                                         -0.031259
# 2                                         -0.031259
# 3                                         -0.031259
# 4                                         -0.031259
#
#    t5_beatles_record_roberta_simmilarity_sum_by_old  \
# 0                                          7.014695
# 1                                          7.014695
# 2                                          7.014695
# 3                                          7.014695
# 4                                          7.014695
#
#    t5_beatles_record_roberta_simmilarity_square_mean_by_old  \
# 0                                           0.446787
# 1                                           0.446787
# 2                                           0.446787
# 3                                           0.446787
# 4                                           0.446787
#
#    t5_beatles_record_roberta_simmilarity_geometric_mean_by_old  \
# 0                                           0.201527
# 1                                           0.201527
# 2                                           0.201527
# 3                                           0.201527
# 4                                           0.201527
#
#    t5_beatles_record_roberta_simmilarity_harmonic_mean_by_old  ...  \
# 0                                           0.030703           ...
# 1                                           0.030703           ...
# 2                                           0.030703           ...
# 3                                           0.030703           ...
# 4                                           0.030703           ...
#
#    t5_beatles_record_roberta_simmilarity  t5_3b_record_top1_fuzz_ratio  \
# 0                               0.001868                          0.12
# 1                               0.321330                          0.14
# 2                               1.000000                          1.00
# 3                               0.599747                          0.14
# 4                               0.303906                          0.00
#
#    t5_3b_record_top2_fuzz_ratio  t5_3b_record_top3_fuzz_ratio  \
# 0                          0.18                          0.30
# 1                          0.15                          0.31
# 2                          0.46                          0.38
# 3                          0.15                          0.23
# 4                          0.00                          0.00
#
#    t5_3b_record_top1_fuzz_partial_ratio  t5_3b_record_top2_fuzz_partial_ratio  \
# 0                                  0.29                                  0.50
# 1                                  0.14                                  0.17
# 2                                  1.00                                  0.50
# 3                                  0.14                                  0.17
# 4                                  0.00                                  0.00
#
#    t5_3b_record_top3_fuzz_partial_ratio  \
# 0                                  0.32
# 1                                  0.43
# 2                                  0.43
# 3                                  0.29
# 4                                  0.00
#
#    t5_3b_record_top1_roberta_simmilarity  \
# 0                               0.001868
# 1                               0.321330
# 2                               1.000000
# 3                               0.599747
# 4                               0.303906
#
#    t5_3b_record_top2_roberta_simmilarity  \
# 0                               0.101491
# 1                               0.437414
# 2                               0.741638
# 3                               0.566922
# 4                               0.261405
#
#    t5_3b_record_top3_roberta_simmilarity
# 0                               0.295024
# 1                               0.388387
# 2                              -0.031259
# 3                               0.019302
# 4                               0.081897
#
# [5 rows x 50 columns]

# %%
for feature in result[0].keys():
    train = mmmm(feature, by='old_idx')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:252: ComplexWarning: Casting complex values to real discards the imaginary part
#   return result.astype(dtype)

# %% [markdown]
# # Crazy simillarity

# %%
all_questions = list(set([str(i) for i in train['question_en'].values]))

# %%
encodes = encoder.encode(all_questions, show_progress_bar=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Batches', max=464.0, style=ProgressStyle(description_widt…

# %%
encoded_questions = {}
for i in range(len(all_questions)):
    encoded_questions[all_questions[i]] = encodes[i]

# %%
encoded_questions = np.load('encoded_questions.npy', allow_pickle=True).item()

# %%
encoded_questions

# %%
list(encoded_questions.items())

# %%
counter = 0
result = {}
for answer, question in tqdm(train[['answer_en', 'question_en']].values):
    try:
        result[counter] = {'answer_question_en_simiilarity_by_roberta': cosine_similarity(encoded_questions[question], encoded_answers[answer])}
    except:
        result[counter] = {'answer_question_en_simiilarity_by_roberta': 0}
        print('woops')
    counter += 1

# %%
train['answer_question_en_simiilarity_by_roberta'] = pd.DataFrame(result).T['answer_question_en_simiilarity_by_roberta']

# %%
train = mmmm('answer_question_en_simiilarity_by_roberta', by='old_idx')
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/dtypes/cast.py:252: ComplexWarning: Casting complex values to real discards the imaginary part
#   return result.astype(dtype)

# %%
train = pd.read_csv('admin.csv')

# %% [markdown]
# ## Google Encoder

# %%
import tensorflow_hub as hub

# %%
embed = hub.load("https://tfhub.dev/google/universal-sentence-encoder/4")
# Out:
# INFO:absl:Using /tmp/tfhub_modules to cache modules.

# %%
all_answers_ru = list(set([str(i) for i in train['answer_ru'].values]))

# %%
encoded_answers_use_raw = embed(all_answers_ru)

# %%
encoded_answers_ru = {}
for i in range(len(all_answers_ru)):
    encoded_answers_ru[all_answers_ru[i]] = encoded_answers_use_raw[i]

# %%
all_questions_ru = list(set([str(i) for i in train['question_ru'].values]))

# %%
encoded_questions_use_raw = embed(all_questions_ru)

# %%
encoded_questions_ru = {}
for i in range(len(all_questions_ru)):
    encoded_questions_ru[all_questions_ru[i]] = encoded_questions_use_raw[i]

# %%
counter = 0
result = {}
for answer, question in tqdm(train[['answer_ru', 'question_ru']].values):
    result[counter] = {'answer_question_ru_simiilarity_by_use': cosine_similarity(np.array(encoded_questions_ru[question]), np.array(encoded_answers_ru[answer]))}
    result[counter] = {'answer_question_ru_simiilarity_by_use': 0}
    counter += 1
# Out:
# HBox(children=(FloatProgress(value=0.0, max=143064.0), HTML(value='')))

# %%
train['answer_question_ru_simiilarity_by_use'] = pd.DataFrame(result).T['answer_question_ru_simiilarity_by_use']

# %%
train = mmmm('answer_question_ru_simiilarity_by_use', by='old_idx')

# %% [markdown]
# # NER

# %%
ners = {}
for k, v in load_json('data/answers_ners.json').items():
    if all(map(lambda x: x in ['B-PER', 'I-PER'], v)):
        ners[k] = 'PER'
    elif all(map(lambda x: x in ['B-LOC', 'I-LOC'], v)):
        ners[k] = 'LOC'
    else:
        ners[k] = 'ORG'

# %%
train['answer_ru_ner'] = [ners[answer] for answer in train['answer_ru'].values]

# %%
result = {}
for k, v in dict(train.groupby(['old_idx', 'answer_ru_ner']).size()).items():
    if k[0] not in result:
        result[k[0]] = {'answer_ru_ner_' + k[1].lower() + '_amount_in_context': v}
    else:
        result[k[0]]['answer_ru_ner_' + k[1].lower() + '_amount_in_context'] = v

temp = pd.DataFrame(result).T.fillna(0)
temp['old_idx'] = temp.index
train = pd.merge(train, temp, on='old_idx')

# %%
cat_features += ['answer_ru_ner']

# %%
fuzya = pd.read_csv('fuzyawuzya.csv')

# %%
fuzya = fuzya.fillna(0)

# %%
fuzya = fuzya.drop(columns=['Unnamed: 0', 'old_idx'])

# %%
train = pd.concat([fuzya, train], axis=1)

# %% [markdown]
# # CatBoost Forever!

# %%
from sklearn.model_selection import train_test_split
from catboost import CatBoostClassifier, CatBoostRegressor
from sklearn.metrics import f1_score, accuracy_score

# %%
temp = train.drop(columns=['old_idx', 'start', 'end', 'stemmed_context_ru', 'stemmed_question_ru', 'stemmed_answer_ru', 'stemmed_context_en', 'stemmed_question_en', 'stemmed_answer_en', 'context_ru', 'question_ru', 'answer_ru', 'context_en', 'question_en', 'answer_en'])

# %%
temp = temp.loc[:,~temp.columns.duplicated()]

# %%
temp = temp.fillna(0)

# %%
ttrain, validation = temp[train['is_answered'] == True], temp[train['is_answered'] == False]

# %%
X_train, y_train = ttrain.drop(columns=['label']), ttrain['label']

# %%
train_size = 0.80
X_train, X_test, y_train, y_test = X_train.iloc[:int(len(X_train.index) * train_size)], X_train.iloc[int(len(X_train.index) * train_size) + 1:], y_train.iloc[:int(len(y_train.index) * train_size)], y_train.iloc[int(len(y_train.index) * train_size) + 1:]

# %%
catboost_classifier = CatBoostClassifier(iterations=3000, depth=3, cat_features=cat_features+text_features)

# %%
catboost_classifier.fit(X_train,
          y_train,
          verbose=True, 
          eval_set=(X_test, y_test))
# Out:
# Learning rate set to 0.054077
# 0:	learn: 0.6214642	test: 0.6271792	best: 0.6271792 (0)	total: 50.1ms	remaining: 2m 30s
# 1:	learn: 0.5554205	test: 0.5657714	best: 0.5657714 (1)	total: 93.3ms	remaining: 2m 19s
# 2:	learn: 0.5036370	test: 0.5181298	best: 0.5181298 (2)	total: 131ms	remaining: 2m 11s
# 3:	learn: 0.4546620	test: 0.4733591	best: 0.4733591 (3)	total: 164ms	remaining: 2m 3s
# 4:	learn: 0.4147905	test: 0.4361501	best: 0.4361501 (4)	total: 195ms	remaining: 1m 56s
# 5:	learn: 0.3778964	test: 0.4011842	best: 0.4011842 (5)	total: 225ms	remaining: 1m 52s
# 6:	learn: 0.3520818	test: 0.3776438	best: 0.3776438 (6)	total: 253ms	remaining: 1m 48s
# 7:	learn: 0.3275469	test: 0.3553921	best: 0.3553921 (7)	total: 290ms	remaining: 1m 48s
# 8:	learn: 0.3065755	test: 0.3362762	best: 0.3362762 (8)	total: 320ms	remaining: 1m 46s
# 9:	learn: 0.2891476	test: 0.3205455	best: 0.3205455 (9)	total: 347ms	remaining: 1m 43s
# 10:	learn: 0.2736181	test: 0.3066302	best: 0.3066302 (10)	total: 379ms	remaining: 1m 42s
# 11:	learn: 0.2604332	test: 0.2943856	best: 0.2943856 (11)	total: 406ms	remaining: 1m 40s
# 12:	learn: 0.2493049	test: 0.2845241	best: 0.2845241 (12)	total: 430ms	remaining: 1m 38s
# 13:	learn: 0.2381736	test: 0.2741766	best: 0.2741766 (13)	total: 471ms	remaining: 1m 40s
# 14:	learn: 0.2306851	test: 0.2680378	best: 0.2680378 (14)	total: 502ms	remaining: 1m 39s
# 15:	learn: 0.2234059	test: 0.2616197	best: 0.2616197 (15)	total: 543ms	remaining: 1m 41s
# 16:	learn: 0.2168950	test: 0.2553003	best: 0.2553003 (16)	total: 584ms	remaining: 1m 42s
# 17:	learn: 0.2112950	test: 0.2503133	best: 0.2503133 (17)	total: 617ms	remaining: 1m 42s
# 18:	learn: 0.2064217	test: 0.2463478	best: 0.2463478 (18)	total: 652ms	remaining: 1m 42s
# 19:	learn: 0.2016360	test: 0.2415771	best: 0.2415771 (19)	total: 689ms	remaining: 1m 42s
# 20:	learn: 0.1975187	test: 0.2380672	best: 0.2380672 (20)	total: 716ms	remaining: 1m 41s
# 21:	learn: 0.1944288	test: 0.2358262	best: 0.2358262 (21)	total: 757ms	remaining: 1m 42s
# 22:	learn: 0.1911528	test: 0.2328301	best: 0.2328301 (22)	total: 786ms	remaining: 1m 41s
# 23:	learn: 0.1887232	test: 0.2309715	best: 0.2309715 (23)	total: 827ms	remaining: 1m 42s
# 24:	learn: 0.1862149	test: 0.2285014	best: 0.2285014 (24)	total: 863ms	remaining: 1m 42s
# 25:	learn: 0.1843305	test: 0.2271298	best: 0.2271298 (25)	total: 909ms	remaining: 1m 44s
# 26:	learn: 0.1820330	test: 0.2250377	best: 0.2250377 (26)	total: 945ms	remaining: 1m 44s
# 27:	learn: 0.1802944	test: 0.2237289	best: 0.2237289 (27)	total: 975ms	remaining: 1m 43s
# 28:	learn: 0.1788174	test: 0.2228979	best: 0.2228979 (28)	total: 1.01s	remaining: 1m 43s
# 29:	learn: 0.1775822	test: 0.2221316	best: 0.2221316 (29)	total: 1.04s	remaining: 1m 43s
# 30:	learn: 0.1762784	test: 0.2211456	best: 0.2211456 (30)	total: 1.08s	remaining: 1m 43s
# 31:	learn: 0.1751307	test: 0.2202891	best: 0.2202891 (31)	total: 1.11s	remaining: 1m 42s
# 32:	learn: 0.1741160	test: 0.2200282	best: 0.2200282 (32)	total: 1.15s	remaining: 1m 43s
# 33:	learn: 0.1732143	test: 0.2198117	best: 0.2198117 (33)	total: 1.19s	remaining: 1m 43s
# 34:	learn: 0.1723532	test: 0.2194167	best: 0.2194167 (34)	total: 1.24s	remaining: 1m 44s
# 35:	learn: 0.1714910	test: 0.2187968	best: 0.2187968 (35)	total: 1.28s	remaining: 1m 45s
# 36:	learn: 0.1705978	test: 0.2179802	best: 0.2179802 (36)	total: 1.31s	remaining: 1m 44s
# 37:	learn: 0.1699881	test: 0.2174529	best: 0.2174529 (37)	total: 1.34s	remaining: 1m 44s
# 38:	learn: 0.1693036	test: 0.2169439	best: 0.2169439 (38)	total: 1.37s	remaining: 1m 44s
# 39:	learn: 0.1686714	test: 0.2167378	best: 0.2167378 (39)	total: 1.4s	remaining: 1m 43s
# 40:	learn: 0.1680593	test: 0.2165039	best: 0.2165039 (40)	total: 1.45s	remaining: 1m 44s
# 124:	learn: 0.1478083	test: 0.2054033	best: 0.2054033 (124)	total: 5.24s	remaining: 2m
# 125:	learn: 0.1476955	test: 0.2054374	best: 0.2054033 (124)	total: 5.29s	remaining: 2m
# 126:	learn: 0.1475044	test: 0.2051637	best: 0.2051637 (126)	total: 5.33s	remaining: 2m
# 127:	learn: 0.1474476	test: 0.2051129	best: 0.2051129 (127)	total: 5.38s	remaining: 2m
# 128:	learn: 0.1473460	test: 0.2049767	best: 0.2049767 (128)	total: 5.42s	remaining: 2m
# 129:	learn: 0.1472919	test: 0.2049979	best: 0.2049767 (128)	total: 5.46s	remaining: 2m
# 130:	learn: 0.1470908	test: 0.2046768	best: 0.2046768 (130)	total: 5.51s	remaining: 2m
# 131:	learn: 0.1469843	test: 0.2047044	best: 0.2046768 (130)	total: 5.57s	remaining: 2m 1s
# 132:	learn: 0.1468943	test: 0.2046219	best: 0.2046219 (132)	total: 5.62s	remaining: 2m 1s
# 133:	learn: 0.1468105	test: 0.2046058	best: 0.2046058 (133)	total: 5.66s	remaining: 2m
# 134:	learn: 0.1467523	test: 0.2045723	best: 0.2045723 (134)	total: 5.69s	remaining: 2m
# 135:	learn: 0.1466542	test: 0.2043801	best: 0.2043801 (135)	total: 5.72s	remaining: 2m
# 136:	learn: 0.1464482	test: 0.2041062	best: 0.2041062 (136)	total: 5.77s	remaining: 2m
# 137:	learn: 0.1463954	test: 0.2040481	best: 0.2040481 (137)	total: 5.82s	remaining: 2m
# 138:	learn: 0.1463716	test: 0.2040127	best: 0.2040127 (138)	total: 5.86s	remaining: 2m
# 139:	learn: 0.1462913	test: 0.2040857	best: 0.2040127 (138)	total: 5.92s	remaining: 2m 1s
# 140:	learn: 0.1462342	test: 0.2040435	best: 0.2040127 (138)	total: 5.96s	remaining: 2m
# 141:	learn: 0.1461354	test: 0.2039822	best: 0.2039822 (141)	total: 6.01s	remaining: 2m
# 142:	learn: 0.1459323	test: 0.2039413	best: 0.2039413 (142)	total: 6.07s	remaining: 2m 1s
# 143:	learn: 0.1458809	test: 0.2039194	best: 0.2039194 (143)	total: 6.11s	remaining: 2m 1s
# 144:	learn: 0.1457883	test: 0.2037978	best: 0.2037978 (144)	total: 6.16s	remaining: 2m 1s
# 145:	learn: 0.1456916	test: 0.2037281	best: 0.2037281 (145)	total: 6.22s	remaining: 2m 1s
# 146:	learn: 0.1456883	test: 0.2037277	best: 0.2037277 (146)	total: 6.27s	remaining: 2m 1s
# 147:	learn: 0.1455250	test: 0.2035885	best: 0.2035885 (147)	total: 6.38s	remaining: 2m 2s
# 148:	learn: 0.1454496	test: 0.2035370	best: 0.2035370 (148)	total: 6.41s	remaining: 2m 2s
# 149:	learn: 0.1454013	test: 0.2035126	best: 0.2035126 (149)	total: 6.45s	remaining: 2m 2s
# 150:	learn: 0.1452750	test: 0.2034994	best: 0.2034994 (150)	total: 6.5s	remaining: 2m 2s
# 151:	learn: 0.1450250	test: 0.2032825	best: 0.2032825 (151)	total: 6.59s	remaining: 2m 3s
# 2999:	learn: 0.0988139	test: 0.1982167	best: 0.1955759 (729)	total: 2m 20s	remaining: 0us
#
# bestTest = 0.1955759254
# bestIteration = 729
#
# Shrink model to first 730 iterations.

# %%
f1_score(catboost_classifier.predict(X_test), y_test) # 0.8655 0.8591
# Out:
# 0.8555972952667167

# %%
predictions = catboost_classifier.predict_proba(validation.drop(columns=['label']))

# %%
answers = list(map(lambda x: x[1], predictions))
answers = pd.concat([pd.Series(answers), train[train['is_answered'] != True]['old_idx'].reset_index()], axis=1)
answers = answers.rename(columns={0: 'proba'})
result = {}
for proba, index, context_index in answers.values:
    if context_index in result:
        if result[context_index][0] < proba:
            result[context_index][0] = proba
            result[context_index][1] = int(index)
    else:
        result[context_index] = [proba, int(index)]
result = [i[1] for i in result.values()]
result = list(train.iloc[result]['answer_ru'])

# %%
answers = list(map(lambda x: x[1], predictions))

# %%
answers = pd.concat([pd.Series(answers), train[train['is_answered'] != True]['old_idx'].reset_index()], axis=1)

# %%
answers = answers.rename(columns={0: 'proba'})

# %%
result = {}
for proba, index, context_index in answers.values:
    if context_index in result:
        if result[context_index][0] < proba:
            result[context_index][0] = proba
            result[context_index][1] = int(index)
    else:
        result[context_index] = [proba, int(index)]

# %%
result = [i[1] for i in result.values()]

# %%
result = list(train.iloc[result]['answer_ru'])

# %%
result
# Out:
# ['Косово',
#  'Sunday Mirror',
#  'Греции',
#  'Амир',
#  'Германия',
#  'Мултана',
#  'Украине',
#  'Россию',
#  'НАТО',
#  'Финляндии',
#  'Эквадора',
#  'Вашингтона',
#  'Рихарда Зорге',
#  'Сирии',
#  'Штайнбрюк',
#  'Пакистане',
#  'AP',
#  'Южного Кавказа',
#  'Трампом',
#  'Газпром',
#  'ГДР',
#  'Украины',
#  'ОБСЕ',
#  'Греции',
#  'Гаити',
#  'Саудовской Аравии',
#  'Берлина',
#  'Кирилл',
#  'Корбан',
#  'Haribo',
#  'Киева',
#  'Другой России',
#  'Россия',
#  'СМИ',
#  'НДПГ',
#  'США',
#  'Италия',
#  'Франциск',
#  'Украины',
#  'Сирии',
#  'DW',
#  'США',
#  'Австрии',
#  'Лубянке',
#  'Украина',
#  'Украину',
#  'ВТО',
#  'Deutsche Post',
#  'Чечни',
#  'Daimler',
#  'Греции',
#  'Украине',
#  'Германии',
#  'Восточной Европы',
#  'Льва Марголина',
#  'Бельгии',
#  'Европарламенте',
#  'В защиту прав избирателей',
#  'Ганновере',
#  'США',
#  'Ирина Прохорова',
#  'Тибета',
#  'Украины',
#  'Украину',
#  'России',
#  'Германии',
#  'США',
#  'Греция',
#  'Триполи',
#  'Facebook',
#  'Госдумы',
#  'Германии',
#  'Москвой',
#  'Чечни',
#  'Россия',
#  'Германии',
#  'США',
#  'Франция',
#  'Владимир Дмитриев',
#  'Саудовской Аравии',
#  'Турции',
#  'Маккейна',
#  'Фольксваген',
#  'Украины',
#  'Иран',
#  'ФБР',
#  'Германии',
#  'Саритов',
#  'Мемориал',
#  'США',
#  'Средиземном море',
#  'Европе',
#  'Герман Греф',
#  'Pegida',
#  'Газпром',
#  'США',
#  'Visa',
#  'Тирасполь',
#  'Google',
#  'Украине',
#  'Израиль',
#  'Вячеслав Поставнин',
#  'УЕФА',
#  'Сноудена',
#  'Луны',
#  'DW',
#  'Россия',
#  'Германии',
#  'BND',
#  'Наших',
#  'ЮКОСа',
#  'ЛНР',
#  'Латвии',
#  'Москвы',
#  'СМИ',
#  'Краснодарского края',
#  'Россией',
#  'Марио Драги',
#  'Photokina',
#  'Песков',
#  'Западную Европу',
#  'Мохаммеда',
#  'Россия',
#  'Украины',
#  'Freedom House',
#  'Facebook',
#  'Украины',
#  'ХДС',
#  'ДОВСЕ',
#  'Григорий Костусев',
#  'Bellingcat',
#  'Халид',
#  'Душанбе',
#  'ОБСЕ',
#  'Украину',
#  'Газпром',
#  'Беларусь',
#  'Геншер',
#  'Саакашвили',
#  'Эд Милибэнд',
#  'США',
#  'Германии',
#  'Польша',
#  'ЕС',
#  'Inka',
#  'Чечне',
#  'Эйзенахе',
#  'Борхарда',
#  'Великобританией',
#  'Греции',
#  'Восточного комитета',
#  'Opel',
#  'Африне',
#  'НАТО',
#  'Молдавии',
#  'Москве',
#  'Vodafone',
#  'Германии',
#  'Германия',
#  'США',
#  'НИСЭПИ',
#  'DW',
#  'Коломойскому',
#  'России',
#  'Мемориал',
#  'России',
#  'Германии',
#  'НТВ',
#  'Молдавии',
#  'Украины',
#  'Украина',
#  'Вернер Файман',
#  'Швейцария',
#  'США',
#  'Украине',
#  'Байнета',
#  'Владимир Путин',
#  'МТС',
#  'Blumm',
#  'СМИ',
#  'Дональда Трампа',
#  'Гельмут Шмидт',
#  'Путин',
#  'DW',
#  'АЭС',
#  'Украины',
#  'Москвы',
#  'Беларуси',
#  'Сирии',
#  'Совета Безопасности ООН',
#  'Киеве',
#  'Эстонии',
#  'Испании',
#  'Восточной Германии',
#  'Советский Союз',
#  'Украине',
#  'Порошенко',
#  'еврозоне',
#  'Украине',
#  'Миклош Харасти',
#  'Лабрис',
#  'Путин',
#  'США',
#  'Керченскую переправу',
#  'Pegida',
#  'АНБ',
#  'НАТО',
#  'ОПЕК',
#  'Германии',
#  'Марави',
#  'Завентема',
#  'НАТО',
#  'GEMA',
#  'RWE',
#  'Группы восьми',
#  'Молдавии',
#  'Opel',
#  'Москве',
#  'Замбии',
#  'Bellingcat',
#  'Иордании',
#  'США',
#  'Россия',
#  'ПВО',
#  'Франции',
#  'Германии',
#  'Владимир Гройсман',
#  'Меркель',
#  'СМИ',
#  'DW',
#  'Germanwings',
#  'Украине',
#  'Москве',
#  'ЮКОСа',
#  'Брюсселе',
#  'Россия',
#  'Германия',
#  'Чечни',
#  'Чехословакии',
#  'Россия',
#  'Гилада Шалита',
#  'Александр Бузгалин',
#  'НДПГ',
#  'DW',
#  'Германии',
#  'Беларуси',
#  'Ливане',
#  'Германию',
#  'Швеции',
#  'Крыму',
#  'США',
#  'Германии',
#  'Токио',
#  'Греции',
#  'МККК',
#  'России',
#  'Гамбурге',
#  'DW',
#  'Facebook',
#  'НАБУ',
#  'Евросоюза',
#  'Welt am Sonntag',
#  'Берлине',
#  'Украины',
#  'ВТБ',
#  'Украиной',
#  'Париже',
#  'Пулково',
#  'Игорь Луценко',
#  'Лукашенко',
#  'Украины',
#  'Дирк Нибель',
#  'Гражданское содействие',
#  'Украине',
#  'Puma',
#  'НДПГ',
#  'Ирака',
#  'DW',
#  'DW',
#  'Буша',
#  'США',
#  'Австрия',
#  'WADA',
#  'Германии',
#  'Украина',
#  'DW',
#  'Верховной рады',
#  'МОК',
#  'Москве',
#  'Opel',
#  'де Кеппер',
#  'Голливуда',
#  'DW',
#  'СМИ',
#  'Сербии',
#  'Еврокомиссии',
#  'Ираке',
#  'Крайстчёрч',
#  'Украине',
#  'Еврокомиссии',
#  'Германии',
#  'Таджикистана',
#  'Deutsche Bank',
#  'РФ',
#  'PGNiG',
#  "Standard & Poor's",
#  'Кремля',
#  'Focus',
#  'России',
#  'Европу',
#  'DW',
#  'Саакашвили',
#  'Евросоюза',
#  'Андрей Нэстасе',
#  'Wikileaks',
#  'Испании',
#  'ЕС',
#  'Борису Немцову',
#  'Башар Асад',
#  'Fitch',
#  'Ашхабад',
#  'Сергея Павлюкевича',
#  'Беларуси',
#  'ВТО',
#  'Бранденбург',
#  'США',
#  'НДПГ',
#  'Киеве',
#  'Берлине',
#  'Джеймс Коми',
#  'МВФ',
#  'СССР',
#  'Германии',
#  'Израиле',
#  'Украине',
#  'Армении',
#  'Испании',
#  'Роспотребнадзора',
#  'Украины',
#  'Германии',
#  'Армении',
#  "Moody's",
#  'СМИ',
#  'Греции',
#  'Минюста',
#  'Хайсы',
#  'Китай',
#  'Boeing',
#  'Торстен Фрингс',
#  'Киргизии',
#  'Кремля',
#  'Беларуси',
#  'Шрёдер',
#  'Перу',
#  'США',
#  'ИГ',
#  'Олегу Навальному',
#  'Украине',
#  'СМИ',
#  'НАТО',
#  'Мосгордумы',
#  'Грузии',
#  'Крыму',
#  'Facebook',
#  'Rammstein',
#  'Россия',
#  'США',
#  'DW',
#  'Черногории',
#  'Москве',
#  'Совета муфтиев',
#  'ЕС',
#  'DW',
#  'Джамаати Таблиг',
#  'Эльзы Кунгаевой',
#  'НАТО',
#  'Deutsche Telekom',
#  'Лейпциге',
#  'DW',
#  'Литвы',
#  'ПАРНАС',
#  'Германии',
#  'Борис Джонсон',
#  'ОПЕК',
#  'Москве',
#  'Бишкек',
#  'Египте',
#  'Украины',
#  'Германии',
#  'Симферопольском бульваре',
#  'Украине',
#  'Россия',
#  'Дмитрия Завадского',
#  'Москва',
#  'СМИ',
#  'Испании',
#  'Pussy Riot',
#  'Казахстана',
#  'Украины',
#  'Ирана',
#  'Израиле',
#  'Сталин',
#  'Forbes',
#  'Латвии',
#  'Дмитрий Дашкевич',
#  'Кельнским собором',
#  'Тюрингии',
#  'Великобритании',
#  'Осло',
#  'Хуан Мануэль Сантос',
#  'Марокко',
#  'Украины',
#  'VGB PowerTech',
#  'Украине',
#  'Шлангенбад',
#  'Македонии',
#  'Греции',
#  'Региональная общественная организация',
#  'Газпрома',
#  'Киргизии',
#  'Париже',
#  'Лаутси',
#  'Петром Порошенко',
#  'Russian Circles',
#  'ОПЕК',
#  'Эквадоре',
#  'Беларуси',
#  'США',
#  'Эритреи',
#  'Трамп',
#  'Россия',
#  'Франция',
#  'ФРГ',
#  'НДПГ',
#  'Штайнмайер',
#  'Толоконникова',
#  'Мосгорсуд',
#  'DW',
#  'НАТО',
#  'СССР',
#  'Беларуси',
#  'Крыма',
#  'Ханс Петер Доскоцил',
#  'Андреас Шоккенхофф',
#  'Филиппин',
#  'Бундестаг',
#  'Государственную думу',
#  'Евросоюз',
#  'Надежду Савченко',
#  'Германии',
#  'РФ',
#  'Великобритании',
#  'России',
#  'Silbermond',
#  'Грасса',
#  'Штази',
#  'Breaking the Silence',
#  'Демпартии',
#  'Россию',
#  'Украины',
#  'Oxfam',
#  'DW',
#  'Сербией',
#  'ЕС',
#  'Москву',
#  'РБК',
#  'Великобритании',
#  'Стокгольме',
#  'ПАРНАСа',
#  'НТВ',
#  'Беларуси',
#  'Украине',
#  'Триумфальной площади',
#  'Volkswagen',
#  'Путиным',
#  'Марио Драги',
#  'Одере',
#  'МОК',
#  'Реал',
#  'США',
#  'Amnesty International',
#  'Грузии',
#  'Нижегородским фондом в поддержку толерантности',
#  'Китае',
#  'Союзного государства',
#  'Беларуси',
#  'Огрызко',
#  'ЦРУ',
#  'Украины',
#  'Бирюлеве',
#  'Беларуси',
#  'России',
#  'Германии',
#  'Киеве',
#  'Украине',
#  'ИГ',
#  'Мюллер',
#  'Вашингтоне',
#  'Косово',
#  'Русской православной церкви',
#  'Беларуси',
#  'ФРГ',
#  'Украины',
#  'Дарфур',
#  'Сирии',
#  'Турции',
#  'ЕСПЧ',
#  'Байконур',
#  'Германии',
#  'DW',
#  'ПАСЕ',
#  'Пирей',
#  'Минске',
#  'Азии',
#  'Европе',
#  'Франции',
#  'Uber',
#  'УЕФА',
#  'СМИ',
#  'Беларусь',
#  'Евросоюза',
#  'США',
#  'Домодедово',
#  'DW',
#  'Москве',
#  'WikiLeaks',
#  'Черногории',
#  'Ципрас',
#  'Джек Лью',
#  'США',
#  'Финляндии',
#  'США',
#  'Ирак',
#  'Армении',
#  'Йемене',
#  'Новосибирске',
#  'Москвы',
#  'Беларуси',
#  'Германии',
#  'Россию',
#  'Сочи',
#  'НАТО',
#  'Украины',
#  'Турции',
#  'Ливия',
#  'Гамбурге',
#  'Красноярске',
#  'Украины',
#  'США',
#  'DW',
#  'Украине',
#  'Германии',
#  'Грузии',
#  'Дубровке',
#  'СДПГ',
#  'Берлине',
#  'ХДС',
#  'Хамида Карзая',
#  'ЕЦБ',
#  'Армении',
#  'ХДС',
#  'Беларуси',
#  'СМИ',
#  'Афганистан',
#  'Shell',
#  'Путина',
#  'Украины',
#  'Twitter',
#  'Opel',
#  'Виннендене',
#  'СИРИЗА',
#  'Украине',
#  'Великобритании',
#  'Алеппо',
#  'Украины',
#  'Сирии',
#  'Гамбурге',
#  'Германии',
#  'Исламского государства',
#  'ЮКОСа',
#  'Саакашвили',
#  'России',
#  'Великобритания',
#  'Airbus',
#  'Каталонии',
#  'Пол Маккартни',
#  'Дамаск',
#  'Скрипаль',
#  'Мохаммед',
#  'МВД',
#  'ВОЗ',
#  'США',
#  'Коломб',
#  'Йоханнис',
#  'Асада',
#  'МВД',
#  'Беларуси',
#  'Лузгин',
#  "Moody's",
#  'Бонне',
#  'Россия',
#  'Украине',
#  'Газпром',
#  'Германии',
#  'Германии',
#  'ФРГ',
#  'Рунете',
#  'СДПГ',
#  'Марокко',
#  'США',
#  'Жанаозене',
#  'Госдума',
#  'СДПГ',
#  'Россия',
#  'Украине',
#  'Стамбуле',
#  'ФСИН',
#  'Гуайдо',
#  'Беларуси',
#  'Алексея Навального',
#  'Москве',
#  'Германии',
#  'BND',
#  'Кубе',
#  'Россия',
#  'Россия',
#  'СССР',
#  'СССР',
#  'Bynet',
#  'СЭЗ',
#  'Audi',
#  'Германии',
#  'Киеву',
#  'Копенгагене',
#  'ОПЕК',
#  'Украины',
#  'Airbus',
#  'Бонн',
#  'ГДР',
#  'Германии',
#  'Украине',
#  'Пхеньян',
#  'Эмден',
#  'Москве',
#  'DW',
#  'Беларуси',
#  'Бельгии',
#  'Берлине',
#  'Когалымавиа',
#  'Бинали Йылдырым',
#  'Катаром',
#  'Вашингтоном',
#  'Германии',
#  'DW',
#  'Греции',
#  'НАТО',
#  'Украины',
#  'Ближнему Востоку',
#  'США',
#  'Эрдогана',
#  'Венгрии',
#  'Украине',
#  'Газа',
#  'Airbus',
#  'Германии',
#  'Ирландии',
#  'Opel',
#  'Крым',
#  'Меркель',
#  'Украины',
#  'Берлине',
#  'Москве',
#  'Швейцарии',
#  'Siemens',
#  'Европарламента',
#  'СМИ',
#  'МИД',
#  'Норвегии',
#  'Иосифа',
#  'Токио',
#  'России',
#  'Греции',
#  'Катманду',
#  'Германии',
#  'Charite',
#  'Германии',
#  'Николя де Ривьер',
#  'Россия',
#  'ОЭСР',
#  'Украине',
#  'России',
#  'Киева',
#  'Реал',
#  'Россия',
#  'Сирии',
#  'Штайнмайер',
#  'Суркова',
#  'Обама',
#  'Домодедово',
#  'Талибан',
#  'Греции',
#  'Нарвы',
#  'Базеле',
#  'Чечни',
#  'Вестервелле',
#  'США',
#  'ЛДПР',
#  'Reuters',
#  'Шотландии',
#  "Standard & Poor's",
#  'Онэксим',
#  'ExxonMobil',
#  'Мюнстере',
#  'Monsanto',
#  'Украины',
#  'Душанбе',
#  'Кэсон',
#  'Египту',
#  'Дагестана',
#  'Франциском',
#  'Украину',
#  'США',
#  'Европе',
#  'Украины',
#  'Ораниенбурге',
#  'BND',
#  'Греция',
#  'Mercedes',
#  'Хезболлах',
#  'США',
#  'Пхёнчхане',
#  'Германии',
#  'Москва',
#  'DW',
#  'Китая',
#  'Германии',
#  'Кундуз',
#  'Гарца',
#  'Зеехофера',
#  'Греции',
#  'Митровицы',
#  'Милане',
#  'Украины',
#  'Сирии',
#  'НАТО',
#  'Украины',
#  'Беларуси',
#  'Гааге',
#  'Opel',
#  'Германии',
#  'ЕС',
#  'Берлина',
#  'DAX',
#  'Telegram',
#  'Немецкий ВПК',
#  'ФРГ',
#  'Facebook',
#  'США',
#  'Германии',
#  'США',
#  'LinkedIn',
#  'Google',
#  'Германии',
#  'Федеральной комиссии по торговле',
#  'Крым',
#  'UNHCR',
#  'Греции',
#  'Греции',
#  'ГРУ',
#  'HRW',
#  'Европарламента',
#  'Великобритании',
#  'Audi',
#  'ICIJ',
#  'Германии',
#  'Ассанжа',
#  'Алеппо',
#  'Крыму',
#  'Доннер',
#  'Московской биржи',
#  'Украине',
#  'Сирии',
#  'Кристине Региц',
#  'Украину',
#  'Amazon',
#  'Азии',
#  'DW',
#  'Турции',
#  'АНБ',
#  'МЭА',
#  'Госдуму',
#  'Роскомнадзора',
#  'Brot für die Welt',
#  'Schneekoppe',
#  'НАТО',
#  'Армении',
#  'Германии',
#  'Австралии',
#  'Каталонии',
#  'Михайловского театра',
#  'Германии',
#  'Берлине',
#  'США',
#  'Бёлля',
#  'ЕС',
#  'IBSF',
#  'Туркмении',
#  'Ленинграда',
#  'США',
#  'Молдавии',
#  'Украины',
#  'Ленинграда',
#  'Украине',
#  'Германии',
#  'Гельфанда',
#  'РФ',
#  'МОК',
#  'Западным Берлином',
#  'Берлином',
#  'ГДР',
#  'DW',
#  'Twitter',
#  'Facebook',
#  'DW',
#  'Сирии',
#  'ФРГ',
#  'Украине',
#  'ГДР',
#  'Греции',
#  'Берлину',
#  'БРИКС',
#  'Германии',
#  'Константин Эггерт',
#  'Болгарии',
#  'Германии',
#  'Германия',
#  'США',
#  'Трамп',
#  'НАТО',
#  'США',
#  'Латвии',
#  'Украину',
#  'Германии',
#  'Кремль',
#  'Россия',
#  'Госдуму',
#  'Госдуме',
#  'Borgward',
#  'Владимир Зеленский',
#  'Паниотто',
#  'Порошенко',
#  'Украины',
#  'Украине',
#  'Украине',
#  'Путин',
#  'Науседа',
#  'Еврокомиссии',
#  'Австрии',
#  'Украине',
#  'Россия',
#  'ООН',
#  'Чечне',
#  'Россия',
#  'Голос',
#  'Мария',
#  'Швеции',
#  'Турции',
#  'Германии',
#  'G20',
#  'Катовице',
#  'Германии',
#  'Украине',
#  'Литвы',
#  'Москвы',
#  'СМИ',
#  'Москве',
#  'Маньетт',
#  'Шоты',
#  'Адама',
#  'ГДР',
#  'Россия',
#  'Хмеймим',
#  'Нидерландов',
#  'Тростенец',
#  'DW',
#  'Израиля',
#  'Сеуты',
#  'Гете',
#  'НПО',
#  'Майстера',
#  'Серебренникова',
#  'Google',
#  'Германии',
#  'Toyota',
#  'Трансстрой',
#  'Ликуд',
#  'Commerzbank',
#  'Украины',
#  'NSU',
#  'The Guardian',
#  'Китай',
#  'Украины',
#  'Германии',
#  'Украине',
#  'Чечне',
#  'Крыма',
#  'Афганистана',
#  'Бразилии',
#  'Украине',
#  'ГУАМ',
#  'Турции',
#  'Кундузе',
#  'Apple',
#  'Росатома',
#  'ООН',
#  'Украины',
#  'Китаю',
#  'Киеве',
#  'АСЕАН',
#  'Мюллер',
#  'OIE',
#  'США',
#  'Боннском земельном краеведческом музее',
#  'Украины',
#  'Украине',
#  'Каннах',
#  'Беларуси',
#  'Москве',
#  'США',
#  'Революция через социальную сеть',
#  'зеленые',
#  'Росавтодор',
#  'DW',
#  'ЕС',
#  'Казахстан',
#  'США',
#  "Moody's",
#  'Газпромом',
#  'Греции',
#  'Шойбле',
#  'Москве',
#  'Германии',
#  'Франции',
#  'DW',
#  'Индии',
#  'Украины',
#  'Airbus',
#  'DW',
#  'Испании',
#  'ИГ',
#  'Германии',
#  'Сирии',
#  'США',
#  'Калашников',
#  'Хузуме',
#  'Гизи',
#  'Кельне',
#  'Беларуси',
#  'Турции',
#  'Йемене',
#  'Украины',
#  'Германии',
#  'Украине',
#  'Уэльсе',
#  'Дэвид Липтон',
#  'Испании',
#  'Болгарии',
#  'Берлина',
#  'AFP',
#  'Австрии',
#  'Порошенко',
#  'МОК',
#  'Францию',
#  'Германии',
#  'Беларуси',
#  'Интерфаксу',
#  'DW',
#  'Риге',
#  'Колумбии',
#  'Сирии',
#  'Белый дом',
#  'ЧАЭС',
#  'Кадыров',
#  'DW',
#  'Душанбе',
#  'ЕСПЧ',
#  'США',
#  'Украины',
#  'Эрдоган',
#  'ПАСЕ',
#  'DW',
#  'Алеппо',
#  'Франции',
#  'Россия',
#  'Франции',
#  'НПЗ',
#  'Арианы Гранде',
#  'Словении',
#  'Сирии',
#  'Приватбанка',
#  ...]

# %%
validation['answer_ru'].values[0]
# Out:
# 'Косово'

# %%
predictions
# Out:
# array([[0.04460124, 0.95539876],
#        [0.04460124, 0.95539876],
#        [0.29217422, 0.70782578],
#        ...,
#        [0.10518228, 0.89481772],
#        [0.97246189, 0.02753811],
#        [0.98286344, 0.01713656]])

# %%
validation['preds'] = list(map(lambda x: x[1], predictions))

# %%
answers = list(map(lambda x: x[1], predictions))

# %%
answers = pd.concat([pd.Series(answers), train[train['is_answered'] != True]['old_idx'].reset_index()], axis=1)

# %%
validation[['answer_ru', 'preds']].head(30)
# Out:
#                     answer_ru     preds
# 108749                 Косово  0.955399
# 108750                 Косово  0.955399
# 108751           Косовом поле  0.707826
# 108752                 Косово  0.955399
# 108753                 Косово  0.955425
# 108754                     ЕС  0.007646
# 108755                 Косово  0.955399
# 108756                 Косово  0.955425
# 108757              Евросоюза  0.003666
# 108758                 Косово  0.955399
# 108759                 Сербии  0.007655
# 108760                Белград  0.008026
# 108761               Приштины  0.007175
# 108762                 Россия  0.005032
# 108763  Югославской Федерации  0.017262
# 108764     Слободан Милошевич  0.023313
# 108765                 Косово  0.955399
# 108766              Стёрджесс  0.231573
# 108767               Солсбери  0.095356
# 108768          Дон Стёрджесс  0.089971
# 108769          Sunday Mirror  0.758530
# 108770              Стёрджесс  0.231573
# 108771               Германии  0.012189
# 108772                   ОПЕК  0.010408
# 108773                   Юлии  0.048429
# 108774               Солсбери  0.094820
# 108775        Сергея Скрипаля  0.020138
# 108776               Британию  0.012559
# 108777           Бернд Ригерт  0.116813
# 108778                     ЕС  0.014600

# %%
validation = train[train['is_answered'] != True]

# %%
answers.groupby(['old_idx']).max([0])
# Out:
#                 0   index
# old_idx
# 7577     0.955425  108765
# 7578     0.758530  108776
# 7579     0.938087  108785
# 7580     0.859016  108797
# 7581     0.869472  108803
# ...           ...     ...
# 14829    0.982722  205693
# 14830    0.751562  205707
# 14831    0.812709  205716
# 14832    0.947594  205734
# 14833    0.894818  205744
#
# [7257 rows x 2 columns]

# %%
list(answers)
# Out:
# ['Косово',
#  'Британию',
#  'Греции',
#  'Амир',
#  'Россия',
#  'Страсбурге',
#  'Сергею Андрушко',
#  'Россию',
#  'России',
#  'Александр Кудашефф',
#  'Беккенбауэр',
#  'Boeing',
#  'Рихарда Зорге',
#  'Путину',
#  'ФРГ',
#  'Афганистане',
#  'Исламское государство',
#  'Киевом',
#  'Катара',
#  'Центральной',
#  'Венгрия',
#  'Украины',
#  'Украины',
#  'Италии',
#  'Гаити',
#  'Тегеран',
#  'Берлина',
#  'Синода РПЦ',
#  'Корбан',
#  'Haribo',
#  'Киева',
#  'Таисию Осипову',
#  'Феликс Кравачек',
#  'Косово',
#  'Нижней Саксонии',
#  'Airbus',
#  'Италия',
#  'Константинопольской православной церкви',
#  'Украины',
#  'Сирии',
#  'Германии',
#  'Южной Корее',
#  'Сергей Руденко',
#  'Константина Котова',
#  'Украина',
#  'СНБО',
#  'Boeing',
#  'Гамбурге',
#  'Instagram',
#  'Mercedes Grand Prix Petronas',
#  'Греции',
#  'Брюсселем',
#  'SIPRI',
#  'Хауна',
#  'Нацбанка',
#  'ФРГ',
#  'Астерикс',
#  'РФ',
#  'Берлине',
#  'США',
#  'Ирина Прохорова',
#  'Европарламенте',
#  'Крыму',
#  'PGNiG',
#  'Германию',
#  'РОИ',
#  'Россией',
#  'Россия',
#  'РФ',
#  'Германии',
#  'Михаил Захаров',
#  'Федерального ведомства по уголовным делам',
#  'Родерих Кизеветтер',
#  'Рамзана Кадырова',
#  'Германии',
#  'Аветисянов',
#  'AFP',
#  'Вивиан Рединг',
#  'Россия',
#  'США',
#  'Турции',
#  'США',
#  'Berliner Zeitung',
#  'Йенс Столтенберг',
#  'Брюсселе',
#  'Международный валютный фонд',
#  'Баррозу',
#  'Кадыров',
#  'Германии',
#  'США',
#  'Италии',
#  'Dow Jones',
#  'Германии',
#  'Pegida',
#  'Газпром',
#  'Паскаль Лами',
#  'Visa',
#  'Швеции',
#  'Рунет',
#  'Reuters',
#  'Германии',
#  'Бирюлеве',
#  'Украина',
#  'Handelsblatt',
#  'Венеры',
#  'ВСК',
#  'Россия',
#  'Nokia',
#  'Чехия',
#  'Медведев',
#  'Константин Ривкин',
#  'Корнет',
#  'Литве',
#  'Чехове',
#  'Первый канал',
#  'Сочи',
#  'Украина',
#  'Монти',
#  'Nikon',
#  'России',
#  'Словакию',
#  'Мохаммеда',
#  'РФ',
#  'Украины',
#  'Януковича',
#  'Facebook',
#  'Германии',
#  'России',
#  'ДОВСЕ',
#  'Некляев',
#  'РФ',
#  'Брюсселе',
#  'ГЭС',
#  'ФРГ',
#  'Украину',
#  'Роснефть',
#  'Беларусь',
#  'ФРГ',
#  'Швеции',
#  'Эхо Москвы',
#  'Иран',
#  'Германии',
#  'Украине',
#  'Европы',
#  'Германия',
#  'Чечне',
#  'Opel',
#  'Берлинским Лувром',
#  'Сербии',
#  'Греции',
#  'Россию',
#  'Opel',
#  'Турции',
#  'Украины',
#  'Молдавии',
#  'Швеции',
#  'Эдварда Сноудена',
#  'Европе',
#  'Азербайджан',
#  'Вашингтона',
#  'НИСЭПИ',
#  'DW',
#  'Коломойскому',
#  'ARD',
#  'Минюсту',
#  'Советском Союзе',
#  'Бах',
#  'Москва',
#  'Оперативной группы',
#  'АР Крым',
#  'Евросоюзе',
#  'Хорватии',
#  'ЕЦБ',
#  'Россия',
#  'Германии',
#  'Польша',
#  'Владимир Путин',
#  'Туркменией',
#  'Bobby',
#  'DW',
#  'Востока',
#  'Билл Клинтон',
#  'Путин',
#  'ФБР',
#  'России',
#  'DW',
#  'Навального',
#  'ФРГ',
#  'Сирии',
#  'Совета Безопасности ООН',
#  'Александра Делеменчук',
#  'Фолькера Виттинга',
#  'Мадрида',
#  'Германии',
#  'России',
#  'Украине',
#  'Украину',
#  'Германии',
#  'Германии',
#  'Женеве',
#  'Бишкеке',
#  'Германией',
#  'США',
#  'Керченскую переправу',
#  'Дрезден',
#  'Берлине',
#  'Афганистане',
#  'Соединенных Штатов',
#  'Украине',
#  'Самира Гуток',
#  'Брюсселе',
#  'НАТО',
#  'США',
#  'Россию',
#  'Евросоюза',
#  'Гагаузия',
#  'Opel',
#  'ВВС',
#  'Замбии',
#  'России',
#  'Германии',
#  'Полански',
#  'Гамбурге',
#  'Германии',
#  'Бельгии',
#  'Гамбурге',
#  'Украины',
#  'Ангелы Меркель',
#  'Российской Федерации',
#  'Россия',
#  'Чехия',
#  'Украине',
#  'Германии',
#  'Миллесгорден',
#  'Грузию',
#  'Сергей Ковалев',
#  'Германия',
#  'Кадырова',
#  'Восточная Германия',
#  'Гамбурге',
#  'Frankfurter Rundschau',
#  'Путин',
#  'НДПГ',
#  'ОПЕК',
#  'Португалия',
#  'Германии',
#  'Израилю',
#  'Гамбурге',
#  'Швеции',
#  'DW',
#  'Сибири',
#  'Саксонии',
#  'dpa',
#  'Евросоюз',
#  'SIPRI',
#  'ОПЕК',
#  'DW',
#  'Беларусью',
#  'Microsoft',
#  'Германии',
#  'Женеве',
#  'Евросоюзу',
#  'Рихард Захарук',
#  'РФ',
#  'ЕС',
#  'Германии',
#  'Берлин',
#  'Пулково',
#  'ВСК',
#  'Femen',
#  'Владимира Путина',
#  'РФ',
#  'России',
#  'Ватикан',
#  'Puma',
#  'Баварии',
#  'Саддам Хусейн',
#  'Таджикистана',
#  'Беларуськалий',
#  'Белом Доме',
#  'США',
#  'Александар Вучич',
#  'РФ',
#  'Саудовская Аравия',
#  'Украина',
#  'DW',
#  'Движения новых сил',
#  'Париже',
#  'Москве',
#  'Opel',
#  'ФРГ',
#  'Вендерс',
#  'Сирия',
#  'Deutsche Telekom',
#  'Италии',
#  'Брюсселя',
#  'Фишер',
#  'Крайстчёрч',
#  'Украине',
#  'Берлина',
#  'Швейцарии',
#  'Таджикистане',
#  'Deutsche Bank',
#  'ОПЕК',
#  'Гамбурге',
#  'Италии',
#  'Удальцов',
#  'Бориса Райтшустера',
#  'Советского Союза',
#  'Ли Кэцян',
#  'Елена Хорошева',
#  'Украины',
#  'Фельсхайму',
#  'Кишинева',
#  'Джулиан Ассанж',
#  'ЭТА',
#  'Украине',
#  'Борису Немцову',
#  'Тиллерсон',
#  'Италия',
#  'Ашхабад',
#  'ВКонтакте',
#  'Германии',
#  'ВТО',
#  'Германия',
#  'Республики Казахстан',
#  'Германии',
#  'Сбербанке',
#  'Тиль Швайгер',
#  'Демократической партии',
#  'Игоря Бураковского',
#  'Россия',
#  'Крым',
#  'Советского Союза',
#  'Европейского университета',
#  'DW',
#  'Россия',
#  'Россия',
#  'НАТО',
#  'Россией',
#  'Абрамяна',
#  "Moody's",
#  'Россия',
#  'Греции',
#  'Мемориал',
#  'Алехнович',
#  'Норвегия',
#  'DW',
#  'Клаудио Писарро',
#  'Казахстана',
#  'Кремля',
#  'Минска',
#  'Шрёдер',
#  'Перу',
#  'Центробанк',
#  'Гамбурге',
#  'Урицким райсудом',
#  'Украине',
#  'СМИ',
#  'Кляйна',
#  'Мосгордумы',
#  'БПЦ',
#  'Крыму',
#  'РФ',
#  'Rammstein',
#  'Германии',
#  'ФРГ',
#  'Центральной Азии',
#  'SIPRI',
#  'Яблоко',
#  'России',
#  'Восточного комитета',
#  'DW',
#  'Таджикистана',
#  'СК',
#  'РФ',
#  'Deutsche Telekom',
#  'Дюссельдорфе',
#  'DW',
#  'Россия',
#  'ПАРНАСа',
#  'Рюген',
#  'Борис Джонсон',
#  'Москвы',
#  'Алексей Навальный',
#  'США',
#  'Египте',
#  'Вера Юрова',
#  'Германии',
#  'Триумфальной площади',
#  'Евросоюза',
#  'ТАСС',
#  'ОРТ',
#  'Москва',
#  'РФ',
#  'Испании',
#  'Igor_nefedov',
#  'Совета безопасности',
#  'Франсуа Олланд',
#  'Россия',
#  'Негев',
#  'Германия',
#  'Билл Гейтс',
#  'Эстонии',
#  'Минске',
#  'Гамбурге',
#  'ФРГ',
#  'ОПЕК',
#  'Осло',
#  'Россия',
#  'Испании',
#  'Бернд Йоханн',
#  'Фукусима',
#  'BMW',
#  'РФ',
#  'Германии',
#  'Антонис Самарас',
#  'Ленинградской области',
#  'Давутоглу',
#  'ООН',
#  'России',
#  'Страсбургский суд по правам человека',
#  'Сергей Руденко',
#  'Берлин',
#  'ОПЕК',
#  'Россией',
#  'Интерфакс',
#  'Fancy Bear',
#  'Лампедуза',
#  'Столтенберг',
#  'Беларуси',
#  'Париже',
#  'ЮАР',
#  'СДПГ',
#  'Украине',
#  'Интерфакс',
#  'Устинов',
#  'Германии',
#  'Карл-Теодор цу Гуттенберг',
#  'МСР',
#  'Украины',
#  'Леонида Кучмы',
#  'Евросоюза',
#  'Украины',
#  'Трампа',
#  'Россия',
#  'Голос',
#  'Евросоюз',
#  'Интерфакс',
#  'Лёв',
#  'Олег Сенцов',
#  'AFP',
#  'Берлин',
#  'Monde',
#  'Грасса',
#  'ГДР',
#  'Breaking the Silence',
#  'Чехии',
#  'Евросоюзом',
#  'Германии',
#  'Великобританию',
#  'Йоахим Руквид',
#  'DW',
#  'России',
#  'Лондон',
#  'Германии',
#  'Великобритании',
#  'Швеции',
#  'Алексей Навальный',
#  'Владимира Кулистикова',
#  'СМИ',
#  'Украине',
#  'Кремль',
#  'Volkswagen',
#  'МИД',
#  'ЕЦБ',
#  'Одере',
#  'РФ',
#  'Бавария',
#  'Детройт',
#  'Киеве',
#  'Хилари Клинтон',
#  'России',
#  'Калашникова',
#  'Москву',
#  'Игорь Шуневич',
#  'Украины',
#  'США',
#  'Владимир Путин',
#  'Мосгорсуде',
#  'Оксана Шелест',
#  'России',
#  'Италия',
#  'Гамбурге',
#  'Украине',
#  'Россия',
#  'ФБР',
#  'Аркадий Дубнов',
#  'Гамбурге',
#  'ВРНС',
#  'Беларуси',
#  'Боннского университета',
#  'Вагнера',
#  'Судана',
#  'Хезболлах',
#  'Сирии',
#  'SIPRI',
#  'Зинсхайма',
#  'ОПЕК',
#  'РФ',
#  'ПАСЕ',
#  'Reuters',
#  'Украины',
#  'Audi',
#  'Германия',
#  'Ле Пен',
#  'Польша',
#  'Hightex GmbH',
#  'Ноордин Мохаммед Топ',
#  'Украине',
#  'Верховной раде',
#  'ЕС',
#  'Домодедово',
#  'Dresden',
#  'Башнефти',
#  'МВФ',
#  'Мило Джукановича',
#  'Греции',
#  'Reuters',
#  'SIPRI',
#  'России',
#  'Иран',
#  'Россия',
#  'Россия',
#  'Саудовской Аравии',
#  'Демократическая коалиция',
#  'США',
#  'Киевом',
#  'ЮАР',
#  'Путина',
#  'Сочи',
#  'Карл-Теодор цу Гуттенберг',
#  'ЛАЗ',
#  'Германии',
#  'Германии',
#  'Олег Кашин',
#  'СМИ',
#  'Чехия',
#  'США',
#  'Гамбурге',
#  'Кремль',
#  'Фарьяб',
#  'Россия',
#  'Следственный комитет',
#  'СДПГ',
#  'Сюзанне Остхоф',
#  'Советского Союза',
#  'Афганистана',
#  'Драги',
#  'Армении',
#  'Фридрих Мерц',
#  'Беларуси',
#  'ЕС',
#  'НАТО',
#  'ExxonMobile',
#  'Москва',
#  'Международную морскую организацию',
#  'Владимира Мединского',
#  'Opel',
#  'SIPRI',
#  'Афинах',
#  'СС',
#  'Франции',
#  'МИД',
#  'Украины',
#  'РФ',
#  'США',
#  'Германии',
#  'Исламского государства',
#  'Ибрагимова',
#  'Абхазии',
#  'ЕС',
#  'Германия',
#  'Frontier Airlines',
#  'Испании',
#  'Елизавета Леонская',
#  'Дамаск',
#  'Snap Fitness',
#  'Гамбурге',
#  'Москве',
#  'РФ',
#  'Пентагон',
#  'Россия',
#  'Румынии',
#  'Гамбурге',
#  'Азарова',
#  'США',
#  'ФРГ',
#  'ОПЕК',
#  'Германии',
#  'Германии',
#  'DW',
#  'Германии',
#  'Рейхстага',
#  'ВТО',
#  'бундестага',
#  'Италия',
#  'СДПГ',
#  'Бельгии',
#  'СБ',
#  'Жанаозене',
#  'Россией',
#  'Германии',
#  'МИД',
#  'ОПЕК',
#  'The Hürriyet Daily',
#  'Алексея Навального',
#  'Путин',
#  'МИД',
#  'Алексея Навального',
#  'Путиным',
#  'Ifo',
#  'АНБ',
#  'Гавана',
#  'Андрея Юрова',
#  'Китай',
#  'Юлии Кантор',
#  'Mashable',
#  'Bynet',
#  'Германии',
#  'России',
#  'Берлине',
#  'ЕС Киев',
#  'ФРГ',
#  'ОПЕК',
#  'Эберхард Шнайдер',
#  'Германией',
#  'Германию',
#  'Гамбурге',
#  'Германии',
#  'DW',
#  'КНДР',
#  'Эмден',
#  'Владимир Путин',
#  'DW',
#  'Казахстаном',
#  'TF 1',
#  'Бенедикт XVI',
#  'России',
#  'Анкары',
#  'Германии',
#  'Петер Альтмайер',
#  'Гамбурге',
#  'DW',
#  'Италии',
#  'НАТО',
#  'Батькивщина',
#  'Бенте Шеллер',
#  'Германии',
#  'Оберхаузен',
#  'Венгрии',
#  'Киев',
#  'ХАМАС',
#  'Airbus',
#  'Германии',
#  'DWглава',
#  'России',
#  'Крым',
#  'Меркель',
#  'Россия',
#  'Гамбурге',
#  'Рурскими университетами',
#  'Швейцарии',
#  'Areva',
#  'ЕС',
#  'Беларуси',
#  'Саркози',
#  'Максиму Белугину',
#  'Reuters',
#  'Мадрида',
#  'Германией',
#  'Федерального объединения немецкой промышленности',
#  'Катманду',
#  'Вакцина',
#  'DW',
#  'Фредерик Угарф',
#  'РФ',
#  'Кельне',
#  'ОЭСР',
#  'Донбасс',
#  'России',
#  'Украине',
#  'Россия',
#  'Россия',
#  'Ахмет Давутоглу',
#  'ФРГ',
#  'Суркова',
#  'Израиля',
#  'Генпрокуратуры',
#  'Афганистан',
#  'ЕЦБ',
#  'ОПЕК',
#  'ООН',
#  'DW',
#  'Frankfurter Rundschau',
#  'Трампа',
#  'ЛДПР',
#  'Стивен Баркли',
#  'Германии',
#  'Великобритании',
#  'РФ',
#  'Украины',
#  'Американской киноакадемии',
#  'Хенрик Бёме',
#  'Германии',
#  'Россия',
#  'Кэсон',
#  'DCNS',
#  'Дагестана',
#  'Passauer Neuen Presse',
#  'Фейгин',
#  'Швеции',
#  'Западом',
#  'Россия',
#  'Равенсбрюк',
#  'BND',
#  'Алексис Ципрас',
#  'Формулу',
#  'Ливане',
#  'США',
#  'Федеральный суд',
#  'Германии',
#  'МИД',
#  'Кабмина',
#  'МВФ',
#  'Германии',
#  'Кундуз',
#  'Гарца',
#  'Италия',
#  'Германии',
#  'Косово',
#  'Берлина',
#  'ГТС',
#  'Москве',
#  'Германии',
#  'Гамбурге',
#  'Россия',
#  'Германии',
#  'Opel',
#  'Россия',
#  'Италии',
#  'Ниццу',
#  'DAX',
#  'Рунета',
#  'Heckler & Koch',
#  'Мулино',
#  'США',
#  'Lockheed Martin',
#  'Бауцен',
#  'Сирии',
#  'DW',
#  'Google',
#  'Грязнова',
#  'Facebook',
#  'Siemens',
#  'Европе',
#  'Греции',
#  'Меркель',
#  'The Telegraph',
#  'Москвы',
#  'Германия',
#  'The Guardian',
#  'России',
#  'Украины',
#  'Aral',
#  'Ассанж',
#  'Алеппо',
#  'НАТО',
#  'Мали',
#  'Путин',
#  'Яндекса',
#  'Сирии',
#  'России',
#  'Шеремета',
#  'Джеффа Безоса',
#  'Мюнхене',
#  'Белграде',
#  'Турции',
#  'Германии',
#  'DW',
#  'России',
#  'LinkedIn',
#  'Виршинг',
#  'Европе',
#  'Москва',
#  'Джермук',
#  'Берлине',
#  'Лондоне',
#  'Каталонии',
#  'Милана',
#  'Ганзейского союза',
#  'Крыму',
#  'СМИ',
#  'Ежи Гедройца',
#  'DW',
#  'Макларена',
#  'Туркмении',
#  'Ленинграда',
#  'Беларусь',
#  'Молдавии',
#  'Донбассом',
#  'России',
#  'Киев',
#  'Германии',
#  'России',
#  'FAZ',
#  'МОК',
#  'Спартака',
#  'Запад',
#  'Запад',
#  'Путина',
#  'Бундестаг',
#  'США',
#  'Шлосберг',
#  'Латакия',
#  'Хофера',
#  'Россия',
#  'ГДР',
#  'Греция',
#  'Хойсген',
#  'Россия',
#  'Китае',
#  'Сибирь',
#  'Брюсселем',
#  'ZSW',
#  'Германия',
#  'РФ',
#  'Трамп',
#  'Германию',
#  'Швеции',
#  'Газпром',
#  'Киевом',
#  'Колю',
#  'России',
#  'Игорь Эйдман',
#  'Игоря Эйдмана',
#  'DW',
#  'Borgward',
#  'Владимир Зеленский',
#  'Слуга народа',
#  'Порошенко',
#  'Швеции',
#  'Сергей Руденко',
#  'Полу Манафорту',
#  'Путин',
#  'Германии',
#  'Еврокомиссии',
#  'России',
#  'Швеции',
#  'DW',
#  'Амстердама',
#  'Чечне',
#  'ЦДУ ТЭК',
#  'Московской области',
#  'Сербии',
#  'Россия',
#  'Россия',
#  'Германии',
#  'Бразилию',
#  'Швеции',
#  'Россия',
#  'Швеции',
#  'Россия',
#  'Медузы',
#  'Александр Плющев',
#  'Россия',
#  'ФРГ',
#  'Шоты',
#  'Бориса Пастернака',
#  'Запад',
#  'Константин Эггерт',
#  'имени Александрова',
#  'Россия',
#  'Тростенец',
#  'Ганновере',
#  'Германия',
#  'Heritage Foundation',
#  'Гете',
#  'Greenpeace',
#  'Майстера',
#  'России',
#  'Ведомости',
#  'DW',
#  'Польше',
#  'Счетная плата',
#  'Кнессет',
#  'Commerzbank',
#  'Партия регионов',
#  'Турции',
#  'НАТО',
#  'Франк Зирен',
#  'Россия',
#  'Исламским государством',
#  'Гамбурге',
#  'Новоселицком',
#  'Швеции',
#  'Центра стратегических исследований',
#  'Air France',
#  'Беларуси',
#  'Грузией',
#  'Стамбуле',
#  'ФРГ',
#  'SIPRI',
#  'ФРГ',
#  'Западной Африке',
#  'Донбассе',
#  'HSBC',
#  'Киеве',
#  'Малайзии',
#  'России',
#  'OIE',
#  'Италия',
#  'Египта',
#  'DW',
#  'Сергей Руденко',
#  'Берлин',
#  'Минск',
#  'Италия',
#  'США',
#  'Вячеслав Дианов',
#  'Россия',
#  'России',
#  'Россия',
#  'Брюсселе',
#  'США',
#  'Путин',
#  'Германия',
#  'Газпромом',
#  'Der Spiegel',
#  'Шар',
#  'Россию',
#  'России',
#  'Московичи',
#  'Минске',
#  'Израиль',
#  'Штюдеман',
#  'Boeing',
#  'Анатолий Пахомов',
#  'DW',
#  'Дахуке',
#  'Германии',
#  'Сирии',
#  'Норвежской академии литературы и свободы слова',
#  'Калашников',
#  'Хузуме',
#  'ФРГ',
#  'Гельзенкирхене',
#  'Гамбурге',
#  'Сирии',
#  'МИД',
#  'Донбассе',
#  'России',
#  'Виктором Орбаном',
#  'Россия',
#  'МВФ',
#  'Fabrilad Contratas SL',
#  'Европу',
#  'Леверкузеном',
#  'Палестинской автономии',
#  'Австрии',
#  'Порошенко',
#  'Хёрман',
#  'Ричарда Ленуара',
#  'РФ',
#  'Беларуси',
#  'Минске',
#  'Чесно',
#  'Риге',
#  'Сантоса',
#  'Сирии',
#  'Белый дом',
#  'SIPRI',
#  'Титиев',
#  'Новых Санжарах',
#  'Германии',
#  'Илье Гущину',
#  'Совет Безопасности ООН',
#  'Россия',
#  'Россия',
#  'Financial Times Deutschland',
#  'Германии',
#  'РФ',
#  'Франции',
#  'Германии',
#  'Россия',
#  'SIPRI',
#  'Трамп',
#  'Гамбурге',
#  'МИД',
#  'Вышлинский',
#  ...]

# %%
answers = list(map(lambda x: x[1], predictions))
answers = pd.concat([pd.Series(answers), train[train['is_answered'] != True]['old_idx'].reset_index()], axis=1)
train.iloc[answers.groupby(['old_idx']).max([0])['index']]['answer_ru'].values
# Out:
# array(['Косово', 'Британию', 'Греции', ..., 'США', 'Советского Союза',
#        'РИА Новости'], dtype=object)

# %%
dict(sorted(list(zip(catboost_classifier.get_feature_importance(), X_train.columns))))

# %%
validation.columns[196]
# Out:
# 'stems_same_stems_ratio_answer_en'

# %%
save_predictions(catboost_classifier.predict_proba(validation.drop(columns=['label'])), filename='pleeeseeees_long')
# Out:
# Successfully saved! Filename:  pleeeseeees_long.jsonl

# %%
def save_predictions(predictions, filename="solution"):
    if '.jsonl' not in filename:
        filename += ".jsonl"
    
    answers = list(map(lambda x: x[1], predictions))
    answers = pd.concat([pd.Series(answers), train[train['is_answered'] != True]['old_idx'].reset_index()], axis=1)
    answers = answers.rename(columns={0: 'proba'})
    result = {}
    for proba, index, context_index in answers.values:
        if context_index in result:
            if result[context_index][0] < proba:
                result[context_index][0] = proba
                result[context_index][1] = int(index)
        else:
            result[context_index] = [proba, int(index)]
    result = [i[1] for i in result.values()]
    result = list(train.iloc[result]['answer_ru'])

    with open(filename, 'w') as fp:
          for i, o in enumerate(result):
              d = {"idx": i, "text": o}
              fp.write(json.dumps(d, ensure_ascii=False)+"\n")
    print("Successfully saved! Filename: ", filename)

# %%
answers
# Out:
# array(['Косово', 'Британию', 'Греции', ..., 'США', 'Советского Союза',
#        'РИА Новости'], dtype=object)
