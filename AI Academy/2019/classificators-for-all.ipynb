# %%
import catboost
import pandas as pd

# %%
train = pd.read_csv('csv/train.csv')

# %%
train
# Out:
#            id  skilled player_team winner_team  duration  pre_game_duration  \
# 0           7        1        dire        dire      2140                 90
# 1           8        0     radiant     radiant      2138                 90
# 2          12        0     radiant     radiant      3547                 90
# 3          13        1        dire     radiant      1878                 90
# 4          14        1        dire     radiant      2232                 90
# 5          15        0        dire     radiant      2706                 90
# 6          19        0     radiant     radiant      2244                 90
# 7          23        1        dire        dire      1014                 90
# 8          25        0        dire        dire      2620                 90
# 9          26        1        dire     radiant       950                 90
# 10         29        0     radiant     radiant      1960                 90
# ...
